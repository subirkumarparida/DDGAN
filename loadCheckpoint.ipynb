# %%
import os
import cv2
import math
import time
import numpy as np
import pandas as pd
import matplotlib
from matplotlib import cm
import matplotlib.pyplot as plt

import torch
import torchvision
import torch.nn as nn
import torch.nn.functional as F
from torchvision import transforms
from torchvision.datasets import ImageFolder
from torchvision.datasets.utils import download_url
from torch.utils.data import random_split, DataLoader, Dataset
from torchsummary import summary

# %%
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
random_seed = 42
torch.manual_seed(random_seed)

# %%
torch.set_printoptions(edgeitems=5)

# %%
def get_default_device():
    """Pick GPU if available, else CPU"""
    if torch.cuda.is_available():
        return torch.device('cuda')
    else:
        return torch.device('cpu')

def to_device(data, device):
    """Move tensor(s) to chosen device"""
    if isinstance(data, (list,tuple)):
        return [to_device(x, device) for x in data]
    return data.to(device, non_blocking=True) #, dtype=torch.float

class DeviceDataLoader():
    """Wrap a dataloader to move data to a device"""
    def __init__(self, dl, device):
        self.dl = dl
        self.device = device
        
    def __iter__(self):
        """Yield a batch of data after moving it to device"""
        for b in self.dl: 
            yield to_device(b, self.device)

    def __len__(self):
        """Number of batches"""
        return len(self.dl)

# %%
device = get_default_device()
print(device)
# Out:
# cuda

# %%
ckpt1 = torch.load('netG_50.pth')
ckpt2 = torch.load('netG_1200.pth')

# %%
print(len(ckpt1.keys()))
print(len(list(ckpt1.keys())))

for key in list(ckpt1.keys()):
    print(key)
# Out:
# 384
# 384
# all_modules.0.weight
# all_modules.0.bias
# all_modules.1.weight
# all_modules.1.bias
# all_modules.2.weight
# all_modules.2.bias
# all_modules.3.GroupNorm_0.style.weight
# all_modules.3.GroupNorm_0.style.bias
# all_modules.3.Conv_0.weight
# all_modules.3.Conv_0.bias
# all_modules.3.Dense_0.weight
# all_modules.3.Dense_0.bias
# all_modules.3.GroupNorm_1.style.weight
# all_modules.3.GroupNorm_1.style.bias
# all_modules.3.Conv_1.weight
# all_modules.3.Conv_1.bias
# all_modules.4.GroupNorm_0.style.weight
# all_modules.4.GroupNorm_0.style.bias
# all_modules.4.Conv_0.weight
# all_modules.4.Conv_0.bias
# all_modules.4.Dense_0.weight
# all_modules.4.Dense_0.bias
# all_modules.4.GroupNorm_1.style.weight
# all_modules.4.GroupNorm_1.style.bias
# all_modules.4.Conv_1.weight
# all_modules.4.Conv_1.bias
# all_modules.5.GroupNorm_0.style.weight
# all_modules.5.GroupNorm_0.style.bias
# all_modules.5.Conv_0.weight
# all_modules.5.Conv_0.bias
# all_modules.5.Dense_0.weight
# all_modules.5.Dense_0.bias
# all_modules.5.GroupNorm_1.style.weight
# all_modules.5.GroupNorm_1.style.bias
# all_modules.5.Conv_1.weight
# all_modules.5.Conv_1.bias
# all_modules.5.Conv_2.weight
# all_modules.5.Conv_2.bias
# all_modules.6.Conv2d_0.weight
# all_modules.6.Conv2d_0.bias
# all_modules.7.GroupNorm_0.style.weight
# all_modules.7.GroupNorm_0.style.bias
# all_modules.7.Conv_0.weight
# all_modules.7.Conv_0.bias
# all_modules.7.Dense_0.weight
# all_modules.7.Dense_0.bias
# all_modules.7.GroupNorm_1.style.weight
# all_modules.7.GroupNorm_1.style.bias
# all_modules.7.Conv_1.weight
# all_modules.7.Conv_1.bias
# all_modules.7.Conv_2.weight
# all_modules.7.Conv_2.bias
# all_modules.8.GroupNorm_0.weight
# all_modules.8.GroupNorm_0.bias
# all_modules.8.NIN_0.W
# all_modules.8.NIN_0.b
# all_modules.8.NIN_1.W
# all_modules.8.NIN_1.b
# all_modules.8.NIN_2.W
# all_modules.8.NIN_2.b
# all_modules.8.NIN_3.W
# all_modules.8.NIN_3.b
# all_modules.9.GroupNorm_0.style.weight
# all_modules.9.GroupNorm_0.style.bias
# all_modules.9.Conv_0.weight
# all_modules.9.Conv_0.bias
# all_modules.9.Dense_0.weight
# all_modules.9.Dense_0.bias
# all_modules.9.GroupNorm_1.style.weight
# all_modules.9.GroupNorm_1.style.bias
# all_modules.9.Conv_1.weight
# all_modules.9.Conv_1.bias
# all_modules.10.GroupNorm_0.weight
# all_modules.10.GroupNorm_0.bias
# all_modules.10.NIN_0.W
# all_modules.10.NIN_0.b
# all_modules.10.NIN_1.W
# all_modules.10.NIN_1.b
# all_modules.10.NIN_2.W
# all_modules.10.NIN_2.b
# all_modules.10.NIN_3.W
# all_modules.10.NIN_3.b
# all_modules.11.GroupNorm_0.style.weight
# all_modules.11.GroupNorm_0.style.bias
# all_modules.11.Conv_0.weight
# all_modules.11.Conv_0.bias
# all_modules.11.Dense_0.weight
# all_modules.11.Dense_0.bias
# all_modules.11.GroupNorm_1.style.weight
# all_modules.11.GroupNorm_1.style.bias
# all_modules.11.Conv_1.weight
# all_modules.11.Conv_1.bias
# all_modules.11.Conv_2.weight
# all_modules.11.Conv_2.bias
# all_modules.12.Conv2d_0.weight
# all_modules.12.Conv2d_0.bias
# all_modules.13.GroupNorm_0.style.weight
# all_modules.13.GroupNorm_0.style.bias
# all_modules.13.Conv_0.weight
# all_modules.13.Conv_0.bias
# all_modules.13.Dense_0.weight
# all_modules.13.Dense_0.bias
# all_modules.13.GroupNorm_1.style.weight
# all_modules.13.GroupNorm_1.style.bias
# all_modules.13.Conv_1.weight
# all_modules.13.Conv_1.bias
# all_modules.14.GroupNorm_0.style.weight
# all_modules.14.GroupNorm_0.style.bias
# all_modules.14.Conv_0.weight
# all_modules.14.Conv_0.bias
# all_modules.14.Dense_0.weight
# all_modules.14.Dense_0.bias
# all_modules.14.GroupNorm_1.style.weight
# all_modules.14.GroupNorm_1.style.bias
# all_modules.14.Conv_1.weight
# all_modules.14.Conv_1.bias
# all_modules.15.GroupNorm_0.style.weight
# all_modules.15.GroupNorm_0.style.bias
# all_modules.15.Conv_0.weight
# all_modules.15.Conv_0.bias
# all_modules.15.Dense_0.weight
# all_modules.15.Dense_0.bias
# all_modules.15.GroupNorm_1.style.weight
# all_modules.15.GroupNorm_1.style.bias
# all_modules.15.Conv_1.weight
# all_modules.15.Conv_1.bias
# all_modules.15.Conv_2.weight
# all_modules.15.Conv_2.bias
# all_modules.16.Conv2d_0.weight
# all_modules.16.Conv2d_0.bias
# all_modules.17.GroupNorm_0.style.weight
# all_modules.17.GroupNorm_0.style.bias
# all_modules.17.Conv_0.weight
# all_modules.17.Conv_0.bias
# all_modules.17.Dense_0.weight
# all_modules.17.Dense_0.bias
# all_modules.17.GroupNorm_1.style.weight
# all_modules.17.GroupNorm_1.style.bias
# all_modules.17.Conv_1.weight
# all_modules.17.Conv_1.bias
# all_modules.18.GroupNorm_0.style.weight
# all_modules.18.GroupNorm_0.style.bias
# all_modules.18.Conv_0.weight
# all_modules.18.Conv_0.bias
# all_modules.18.Dense_0.weight
# all_modules.18.Dense_0.bias
# all_modules.18.GroupNorm_1.style.weight
# all_modules.18.GroupNorm_1.style.bias
# all_modules.18.Conv_1.weight
# all_modules.18.Conv_1.bias
# all_modules.19.GroupNorm_0.style.weight
# all_modules.19.GroupNorm_0.style.bias
# all_modules.19.Conv_0.weight
# all_modules.19.Conv_0.bias
# all_modules.19.Dense_0.weight
# all_modules.19.Dense_0.bias
# all_modules.19.GroupNorm_1.style.weight
# all_modules.19.GroupNorm_1.style.bias
# all_modules.19.Conv_1.weight
# all_modules.19.Conv_1.bias
# all_modules.20.GroupNorm_0.weight
# all_modules.20.GroupNorm_0.bias
# all_modules.20.NIN_0.W
# all_modules.20.NIN_0.b
# all_modules.20.NIN_1.W
# all_modules.20.NIN_1.b
# all_modules.20.NIN_2.W
# all_modules.20.NIN_2.b
# all_modules.20.NIN_3.W
# all_modules.20.NIN_3.b
# all_modules.21.GroupNorm_0.style.weight
# all_modules.21.GroupNorm_0.style.bias
# all_modules.21.Conv_0.weight
# all_modules.21.Conv_0.bias
# all_modules.21.Dense_0.weight
# all_modules.21.Dense_0.bias
# all_modules.21.GroupNorm_1.style.weight
# all_modules.21.GroupNorm_1.style.bias
# all_modules.21.Conv_1.weight
# all_modules.21.Conv_1.bias
# all_modules.22.GroupNorm_0.style.weight
# all_modules.22.GroupNorm_0.style.bias
# all_modules.22.Conv_0.weight
# all_modules.22.Conv_0.bias
# all_modules.22.Dense_0.weight
# all_modules.22.Dense_0.bias
# all_modules.22.GroupNorm_1.style.weight
# all_modules.22.GroupNorm_1.style.bias
# all_modules.22.Conv_1.weight
# all_modules.22.Conv_1.bias
# all_modules.22.Conv_2.weight
# all_modules.22.Conv_2.bias
# all_modules.23.GroupNorm_0.style.weight
# all_modules.23.GroupNorm_0.style.bias
# all_modules.23.Conv_0.weight
# all_modules.23.Conv_0.bias
# all_modules.23.Dense_0.weight
# all_modules.23.Dense_0.bias
# all_modules.23.GroupNorm_1.style.weight
# all_modules.23.GroupNorm_1.style.bias
# all_modules.23.Conv_1.weight
# all_modules.23.Conv_1.bias
# all_modules.23.Conv_2.weight
# all_modules.23.Conv_2.bias
# all_modules.24.GroupNorm_0.style.weight
# all_modules.24.GroupNorm_0.style.bias
# all_modules.24.Conv_0.weight
# all_modules.24.Conv_0.bias
# all_modules.24.Dense_0.weight
# all_modules.24.Dense_0.bias
# all_modules.24.GroupNorm_1.style.weight
# all_modules.24.GroupNorm_1.style.bias
# all_modules.24.Conv_1.weight
# all_modules.24.Conv_1.bias
# all_modules.24.Conv_2.weight
# all_modules.24.Conv_2.bias
# all_modules.25.GroupNorm_0.style.weight
# all_modules.25.GroupNorm_0.style.bias
# all_modules.25.Conv_0.weight
# all_modules.25.Conv_0.bias
# all_modules.25.Dense_0.weight
# all_modules.25.Dense_0.bias
# all_modules.25.GroupNorm_1.style.weight
# all_modules.25.GroupNorm_1.style.bias
# all_modules.25.Conv_1.weight
# all_modules.25.Conv_1.bias
# all_modules.25.Conv_2.weight
# all_modules.25.Conv_2.bias
# all_modules.26.GroupNorm_0.style.weight
# all_modules.26.GroupNorm_0.style.bias
# all_modules.26.Conv_0.weight
# all_modules.26.Conv_0.bias
# all_modules.26.Dense_0.weight
# all_modules.26.Dense_0.bias
# all_modules.26.GroupNorm_1.style.weight
# all_modules.26.GroupNorm_1.style.bias
# all_modules.26.Conv_1.weight
# all_modules.26.Conv_1.bias
# all_modules.26.Conv_2.weight
# all_modules.26.Conv_2.bias
# all_modules.27.GroupNorm_0.style.weight
# all_modules.27.GroupNorm_0.style.bias
# all_modules.27.Conv_0.weight
# all_modules.27.Conv_0.bias
# all_modules.27.Dense_0.weight
# all_modules.27.Dense_0.bias
# all_modules.27.GroupNorm_1.style.weight
# all_modules.27.GroupNorm_1.style.bias
# all_modules.27.Conv_1.weight
# all_modules.27.Conv_1.bias
# all_modules.27.Conv_2.weight
# all_modules.27.Conv_2.bias
# all_modules.28.GroupNorm_0.style.weight
# all_modules.28.GroupNorm_0.style.bias
# all_modules.28.Conv_0.weight
# all_modules.28.Conv_0.bias
# all_modules.28.Dense_0.weight
# all_modules.28.Dense_0.bias
# all_modules.28.GroupNorm_1.style.weight
# all_modules.28.GroupNorm_1.style.bias
# all_modules.28.Conv_1.weight
# all_modules.28.Conv_1.bias
# all_modules.28.Conv_2.weight
# all_modules.28.Conv_2.bias
# all_modules.29.GroupNorm_0.style.weight
# all_modules.29.GroupNorm_0.style.bias
# all_modules.29.Conv_0.weight
# all_modules.29.Conv_0.bias
# all_modules.29.Dense_0.weight
# all_modules.29.Dense_0.bias
# all_modules.29.GroupNorm_1.style.weight
# all_modules.29.GroupNorm_1.style.bias
# all_modules.29.Conv_1.weight
# all_modules.29.Conv_1.bias
# all_modules.29.Conv_2.weight
# all_modules.29.Conv_2.bias
# all_modules.30.GroupNorm_0.style.weight
# all_modules.30.GroupNorm_0.style.bias
# all_modules.30.Conv_0.weight
# all_modules.30.Conv_0.bias
# all_modules.30.Dense_0.weight
# all_modules.30.Dense_0.bias
# all_modules.30.GroupNorm_1.style.weight
# all_modules.30.GroupNorm_1.style.bias
# all_modules.30.Conv_1.weight
# all_modules.30.Conv_1.bias
# all_modules.30.Conv_2.weight
# all_modules.30.Conv_2.bias
# all_modules.31.GroupNorm_0.style.weight
# all_modules.31.GroupNorm_0.style.bias
# all_modules.31.Conv_0.weight
# all_modules.31.Conv_0.bias
# all_modules.31.Dense_0.weight
# all_modules.31.Dense_0.bias
# all_modules.31.GroupNorm_1.style.weight
# all_modules.31.GroupNorm_1.style.bias
# all_modules.31.Conv_1.weight
# all_modules.31.Conv_1.bias
# all_modules.31.Conv_2.weight
# all_modules.31.Conv_2.bias
# all_modules.32.GroupNorm_0.style.weight
# all_modules.32.GroupNorm_0.style.bias
# all_modules.32.Conv_0.weight
# all_modules.32.Conv_0.bias
# all_modules.32.Dense_0.weight
# all_modules.32.Dense_0.bias
# all_modules.32.GroupNorm_1.style.weight
# all_modules.32.GroupNorm_1.style.bias
# all_modules.32.Conv_1.weight
# all_modules.32.Conv_1.bias
# all_modules.32.Conv_2.weight
# all_modules.32.Conv_2.bias
# all_modules.33.GroupNorm_0.weight
# all_modules.33.GroupNorm_0.bias
# all_modules.33.NIN_0.W
# all_modules.33.NIN_0.b
# all_modules.33.NIN_1.W
# all_modules.33.NIN_1.b
# all_modules.33.NIN_2.W
# all_modules.33.NIN_2.b
# all_modules.33.NIN_3.W
# all_modules.33.NIN_3.b
# all_modules.34.GroupNorm_0.style.weight
# all_modules.34.GroupNorm_0.style.bias
# all_modules.34.Conv_0.weight
# all_modules.34.Conv_0.bias
# all_modules.34.Dense_0.weight
# all_modules.34.Dense_0.bias
# all_modules.34.GroupNorm_1.style.weight
# all_modules.34.GroupNorm_1.style.bias
# all_modules.34.Conv_1.weight
# all_modules.34.Conv_1.bias
# all_modules.34.Conv_2.weight
# all_modules.34.Conv_2.bias
# all_modules.35.GroupNorm_0.style.weight
# all_modules.35.GroupNorm_0.style.bias
# all_modules.35.Conv_0.weight
# all_modules.35.Conv_0.bias
# all_modules.35.Dense_0.weight
# all_modules.35.Dense_0.bias
# all_modules.35.GroupNorm_1.style.weight
# all_modules.35.GroupNorm_1.style.bias
# all_modules.35.Conv_1.weight
# all_modules.35.Conv_1.bias
# all_modules.35.Conv_2.weight
# all_modules.35.Conv_2.bias
# all_modules.36.GroupNorm_0.style.weight
# all_modules.36.GroupNorm_0.style.bias
# all_modules.36.Conv_0.weight
# all_modules.36.Conv_0.bias
# all_modules.36.Dense_0.weight
# all_modules.36.Dense_0.bias
# all_modules.36.GroupNorm_1.style.weight
# all_modules.36.GroupNorm_1.style.bias
# all_modules.36.Conv_1.weight
# all_modules.36.Conv_1.bias
# all_modules.36.Conv_2.weight
# all_modules.36.Conv_2.bias
# all_modules.37.GroupNorm_0.style.weight
# all_modules.37.GroupNorm_0.style.bias
# all_modules.37.Conv_0.weight
# all_modules.37.Conv_0.bias
# all_modules.37.Dense_0.weight
# all_modules.37.Dense_0.bias
# all_modules.37.GroupNorm_1.style.weight
# all_modules.37.GroupNorm_1.style.bias
# all_modules.37.Conv_1.weight
# all_modules.37.Conv_1.bias
# all_modules.37.Conv_2.weight
# all_modules.37.Conv_2.bias
# all_modules.38.weight
# all_modules.38.bias
# all_modules.39.weight
# all_modules.39.bias
# z_transform.1.weight
# z_transform.1.bias
# z_transform.3.weight
# z_transform.3.bias
# z_transform.5.weight
# z_transform.5.bias
# z_transform.7.weight
# z_transform.7.bias
# z_transform.9.weight
# z_transform.9.bias

# %%
print(len(ckpt2.keys()))
print(len(list(ckpt2.keys())))

for key in list(ckpt2.keys()):
    print(key)
# Out:
# 384
# 384
# module.all_modules.0.weight
# module.all_modules.0.bias
# module.all_modules.1.weight
# module.all_modules.1.bias
# module.all_modules.2.weight
# module.all_modules.2.bias
# module.all_modules.3.GroupNorm_0.style.weight
# module.all_modules.3.GroupNorm_0.style.bias
# module.all_modules.3.Conv_0.weight
# module.all_modules.3.Conv_0.bias
# module.all_modules.3.Dense_0.weight
# module.all_modules.3.Dense_0.bias
# module.all_modules.3.GroupNorm_1.style.weight
# module.all_modules.3.GroupNorm_1.style.bias
# module.all_modules.3.Conv_1.weight
# module.all_modules.3.Conv_1.bias
# module.all_modules.4.GroupNorm_0.style.weight
# module.all_modules.4.GroupNorm_0.style.bias
# module.all_modules.4.Conv_0.weight
# module.all_modules.4.Conv_0.bias
# module.all_modules.4.Dense_0.weight
# module.all_modules.4.Dense_0.bias
# module.all_modules.4.GroupNorm_1.style.weight
# module.all_modules.4.GroupNorm_1.style.bias
# module.all_modules.4.Conv_1.weight
# module.all_modules.4.Conv_1.bias
# module.all_modules.5.GroupNorm_0.style.weight
# module.all_modules.5.GroupNorm_0.style.bias
# module.all_modules.5.Conv_0.weight
# module.all_modules.5.Conv_0.bias
# module.all_modules.5.Dense_0.weight
# module.all_modules.5.Dense_0.bias
# module.all_modules.5.GroupNorm_1.style.weight
# module.all_modules.5.GroupNorm_1.style.bias
# module.all_modules.5.Conv_1.weight
# module.all_modules.5.Conv_1.bias
# module.all_modules.5.Conv_2.weight
# module.all_modules.5.Conv_2.bias
# module.all_modules.6.Conv2d_0.weight
# module.all_modules.6.Conv2d_0.bias
# module.all_modules.7.GroupNorm_0.style.weight
# module.all_modules.7.GroupNorm_0.style.bias
# module.all_modules.7.Conv_0.weight
# module.all_modules.7.Conv_0.bias
# module.all_modules.7.Dense_0.weight
# module.all_modules.7.Dense_0.bias
# module.all_modules.7.GroupNorm_1.style.weight
# module.all_modules.7.GroupNorm_1.style.bias
# module.all_modules.7.Conv_1.weight
# module.all_modules.7.Conv_1.bias
# module.all_modules.7.Conv_2.weight
# module.all_modules.7.Conv_2.bias
# module.all_modules.8.GroupNorm_0.weight
# module.all_modules.8.GroupNorm_0.bias
# module.all_modules.8.NIN_0.W
# module.all_modules.8.NIN_0.b
# module.all_modules.8.NIN_1.W
# module.all_modules.8.NIN_1.b
# module.all_modules.8.NIN_2.W
# module.all_modules.8.NIN_2.b
# module.all_modules.8.NIN_3.W
# module.all_modules.8.NIN_3.b
# module.all_modules.9.GroupNorm_0.style.weight
# module.all_modules.9.GroupNorm_0.style.bias
# module.all_modules.9.Conv_0.weight
# module.all_modules.9.Conv_0.bias
# module.all_modules.9.Dense_0.weight
# module.all_modules.9.Dense_0.bias
# module.all_modules.9.GroupNorm_1.style.weight
# module.all_modules.9.GroupNorm_1.style.bias
# module.all_modules.9.Conv_1.weight
# module.all_modules.9.Conv_1.bias
# module.all_modules.10.GroupNorm_0.weight
# module.all_modules.10.GroupNorm_0.bias
# module.all_modules.10.NIN_0.W
# module.all_modules.10.NIN_0.b
# module.all_modules.10.NIN_1.W
# module.all_modules.10.NIN_1.b
# module.all_modules.10.NIN_2.W
# module.all_modules.10.NIN_2.b
# module.all_modules.10.NIN_3.W
# module.all_modules.10.NIN_3.b
# module.all_modules.11.GroupNorm_0.style.weight
# module.all_modules.11.GroupNorm_0.style.bias
# module.all_modules.11.Conv_0.weight
# module.all_modules.11.Conv_0.bias
# module.all_modules.11.Dense_0.weight
# module.all_modules.11.Dense_0.bias
# module.all_modules.11.GroupNorm_1.style.weight
# module.all_modules.11.GroupNorm_1.style.bias
# module.all_modules.11.Conv_1.weight
# module.all_modules.11.Conv_1.bias
# module.all_modules.11.Conv_2.weight
# module.all_modules.11.Conv_2.bias
# module.all_modules.12.Conv2d_0.weight
# module.all_modules.12.Conv2d_0.bias
# module.all_modules.13.GroupNorm_0.style.weight
# module.all_modules.13.GroupNorm_0.style.bias
# module.all_modules.13.Conv_0.weight
# module.all_modules.13.Conv_0.bias
# module.all_modules.13.Dense_0.weight
# module.all_modules.13.Dense_0.bias
# module.all_modules.13.GroupNorm_1.style.weight
# module.all_modules.13.GroupNorm_1.style.bias
# module.all_modules.13.Conv_1.weight
# module.all_modules.13.Conv_1.bias
# module.all_modules.14.GroupNorm_0.style.weight
# module.all_modules.14.GroupNorm_0.style.bias
# module.all_modules.14.Conv_0.weight
# module.all_modules.14.Conv_0.bias
# module.all_modules.14.Dense_0.weight
# module.all_modules.14.Dense_0.bias
# module.all_modules.14.GroupNorm_1.style.weight
# module.all_modules.14.GroupNorm_1.style.bias
# module.all_modules.14.Conv_1.weight
# module.all_modules.14.Conv_1.bias
# module.all_modules.15.GroupNorm_0.style.weight
# module.all_modules.15.GroupNorm_0.style.bias
# module.all_modules.15.Conv_0.weight
# module.all_modules.15.Conv_0.bias
# module.all_modules.15.Dense_0.weight
# module.all_modules.15.Dense_0.bias
# module.all_modules.15.GroupNorm_1.style.weight
# module.all_modules.15.GroupNorm_1.style.bias
# module.all_modules.15.Conv_1.weight
# module.all_modules.15.Conv_1.bias
# module.all_modules.15.Conv_2.weight
# module.all_modules.15.Conv_2.bias
# module.all_modules.16.Conv2d_0.weight
# module.all_modules.16.Conv2d_0.bias
# module.all_modules.17.GroupNorm_0.style.weight
# module.all_modules.17.GroupNorm_0.style.bias
# module.all_modules.17.Conv_0.weight
# module.all_modules.17.Conv_0.bias
# module.all_modules.17.Dense_0.weight
# module.all_modules.17.Dense_0.bias
# module.all_modules.17.GroupNorm_1.style.weight
# module.all_modules.17.GroupNorm_1.style.bias
# module.all_modules.17.Conv_1.weight
# module.all_modules.17.Conv_1.bias
# module.all_modules.18.GroupNorm_0.style.weight
# module.all_modules.18.GroupNorm_0.style.bias
# module.all_modules.18.Conv_0.weight
# module.all_modules.18.Conv_0.bias
# module.all_modules.18.Dense_0.weight
# module.all_modules.18.Dense_0.bias
# module.all_modules.18.GroupNorm_1.style.weight
# module.all_modules.18.GroupNorm_1.style.bias
# module.all_modules.18.Conv_1.weight
# module.all_modules.18.Conv_1.bias
# module.all_modules.19.GroupNorm_0.style.weight
# module.all_modules.19.GroupNorm_0.style.bias
# module.all_modules.19.Conv_0.weight
# module.all_modules.19.Conv_0.bias
# module.all_modules.19.Dense_0.weight
# module.all_modules.19.Dense_0.bias
# module.all_modules.19.GroupNorm_1.style.weight
# module.all_modules.19.GroupNorm_1.style.bias
# module.all_modules.19.Conv_1.weight
# module.all_modules.19.Conv_1.bias
# module.all_modules.20.GroupNorm_0.weight
# module.all_modules.20.GroupNorm_0.bias
# module.all_modules.20.NIN_0.W
# module.all_modules.20.NIN_0.b
# module.all_modules.20.NIN_1.W
# module.all_modules.20.NIN_1.b
# module.all_modules.20.NIN_2.W
# module.all_modules.20.NIN_2.b
# module.all_modules.20.NIN_3.W
# module.all_modules.20.NIN_3.b
# module.all_modules.21.GroupNorm_0.style.weight
# module.all_modules.21.GroupNorm_0.style.bias
# module.all_modules.21.Conv_0.weight
# module.all_modules.21.Conv_0.bias
# module.all_modules.21.Dense_0.weight
# module.all_modules.21.Dense_0.bias
# module.all_modules.21.GroupNorm_1.style.weight
# module.all_modules.21.GroupNorm_1.style.bias
# module.all_modules.21.Conv_1.weight
# module.all_modules.21.Conv_1.bias
# module.all_modules.22.GroupNorm_0.style.weight
# module.all_modules.22.GroupNorm_0.style.bias
# module.all_modules.22.Conv_0.weight
# module.all_modules.22.Conv_0.bias
# module.all_modules.22.Dense_0.weight
# module.all_modules.22.Dense_0.bias
# module.all_modules.22.GroupNorm_1.style.weight
# module.all_modules.22.GroupNorm_1.style.bias
# module.all_modules.22.Conv_1.weight
# module.all_modules.22.Conv_1.bias
# module.all_modules.22.Conv_2.weight
# module.all_modules.22.Conv_2.bias
# module.all_modules.23.GroupNorm_0.style.weight
# module.all_modules.23.GroupNorm_0.style.bias
# module.all_modules.23.Conv_0.weight
# module.all_modules.23.Conv_0.bias
# module.all_modules.23.Dense_0.weight
# module.all_modules.23.Dense_0.bias
# module.all_modules.23.GroupNorm_1.style.weight
# module.all_modules.23.GroupNorm_1.style.bias
# module.all_modules.23.Conv_1.weight
# module.all_modules.23.Conv_1.bias
# module.all_modules.23.Conv_2.weight
# module.all_modules.23.Conv_2.bias
# module.all_modules.24.GroupNorm_0.style.weight
# module.all_modules.24.GroupNorm_0.style.bias
# module.all_modules.24.Conv_0.weight
# module.all_modules.24.Conv_0.bias
# module.all_modules.24.Dense_0.weight
# module.all_modules.24.Dense_0.bias
# module.all_modules.24.GroupNorm_1.style.weight
# module.all_modules.24.GroupNorm_1.style.bias
# module.all_modules.24.Conv_1.weight
# module.all_modules.24.Conv_1.bias
# module.all_modules.24.Conv_2.weight
# module.all_modules.24.Conv_2.bias
# module.all_modules.25.GroupNorm_0.style.weight
# module.all_modules.25.GroupNorm_0.style.bias
# module.all_modules.25.Conv_0.weight
# module.all_modules.25.Conv_0.bias
# module.all_modules.25.Dense_0.weight
# module.all_modules.25.Dense_0.bias
# module.all_modules.25.GroupNorm_1.style.weight
# module.all_modules.25.GroupNorm_1.style.bias
# module.all_modules.25.Conv_1.weight
# module.all_modules.25.Conv_1.bias
# module.all_modules.25.Conv_2.weight
# module.all_modules.25.Conv_2.bias
# module.all_modules.26.GroupNorm_0.style.weight
# module.all_modules.26.GroupNorm_0.style.bias
# module.all_modules.26.Conv_0.weight
# module.all_modules.26.Conv_0.bias
# module.all_modules.26.Dense_0.weight
# module.all_modules.26.Dense_0.bias
# module.all_modules.26.GroupNorm_1.style.weight
# module.all_modules.26.GroupNorm_1.style.bias
# module.all_modules.26.Conv_1.weight
# module.all_modules.26.Conv_1.bias
# module.all_modules.26.Conv_2.weight
# module.all_modules.26.Conv_2.bias
# module.all_modules.27.GroupNorm_0.style.weight
# module.all_modules.27.GroupNorm_0.style.bias
# module.all_modules.27.Conv_0.weight
# module.all_modules.27.Conv_0.bias
# module.all_modules.27.Dense_0.weight
# module.all_modules.27.Dense_0.bias
# module.all_modules.27.GroupNorm_1.style.weight
# module.all_modules.27.GroupNorm_1.style.bias
# module.all_modules.27.Conv_1.weight
# module.all_modules.27.Conv_1.bias
# module.all_modules.27.Conv_2.weight
# module.all_modules.27.Conv_2.bias
# module.all_modules.28.GroupNorm_0.style.weight
# module.all_modules.28.GroupNorm_0.style.bias
# module.all_modules.28.Conv_0.weight
# module.all_modules.28.Conv_0.bias
# module.all_modules.28.Dense_0.weight
# module.all_modules.28.Dense_0.bias
# module.all_modules.28.GroupNorm_1.style.weight
# module.all_modules.28.GroupNorm_1.style.bias
# module.all_modules.28.Conv_1.weight
# module.all_modules.28.Conv_1.bias
# module.all_modules.28.Conv_2.weight
# module.all_modules.28.Conv_2.bias
# module.all_modules.29.GroupNorm_0.style.weight
# module.all_modules.29.GroupNorm_0.style.bias
# module.all_modules.29.Conv_0.weight
# module.all_modules.29.Conv_0.bias
# module.all_modules.29.Dense_0.weight
# module.all_modules.29.Dense_0.bias
# module.all_modules.29.GroupNorm_1.style.weight
# module.all_modules.29.GroupNorm_1.style.bias
# module.all_modules.29.Conv_1.weight
# module.all_modules.29.Conv_1.bias
# module.all_modules.29.Conv_2.weight
# module.all_modules.29.Conv_2.bias
# module.all_modules.30.GroupNorm_0.style.weight
# module.all_modules.30.GroupNorm_0.style.bias
# module.all_modules.30.Conv_0.weight
# module.all_modules.30.Conv_0.bias
# module.all_modules.30.Dense_0.weight
# module.all_modules.30.Dense_0.bias
# module.all_modules.30.GroupNorm_1.style.weight
# module.all_modules.30.GroupNorm_1.style.bias
# module.all_modules.30.Conv_1.weight
# module.all_modules.30.Conv_1.bias
# module.all_modules.30.Conv_2.weight
# module.all_modules.30.Conv_2.bias
# module.all_modules.31.GroupNorm_0.style.weight
# module.all_modules.31.GroupNorm_0.style.bias
# module.all_modules.31.Conv_0.weight
# module.all_modules.31.Conv_0.bias
# module.all_modules.31.Dense_0.weight
# module.all_modules.31.Dense_0.bias
# module.all_modules.31.GroupNorm_1.style.weight
# module.all_modules.31.GroupNorm_1.style.bias
# module.all_modules.31.Conv_1.weight
# module.all_modules.31.Conv_1.bias
# module.all_modules.31.Conv_2.weight
# module.all_modules.31.Conv_2.bias
# module.all_modules.32.GroupNorm_0.style.weight
# module.all_modules.32.GroupNorm_0.style.bias
# module.all_modules.32.Conv_0.weight
# module.all_modules.32.Conv_0.bias
# module.all_modules.32.Dense_0.weight
# module.all_modules.32.Dense_0.bias
# module.all_modules.32.GroupNorm_1.style.weight
# module.all_modules.32.GroupNorm_1.style.bias
# module.all_modules.32.Conv_1.weight
# module.all_modules.32.Conv_1.bias
# module.all_modules.32.Conv_2.weight
# module.all_modules.32.Conv_2.bias
# module.all_modules.33.GroupNorm_0.weight
# module.all_modules.33.GroupNorm_0.bias
# module.all_modules.33.NIN_0.W
# module.all_modules.33.NIN_0.b
# module.all_modules.33.NIN_1.W
# module.all_modules.33.NIN_1.b
# module.all_modules.33.NIN_2.W
# module.all_modules.33.NIN_2.b
# module.all_modules.33.NIN_3.W
# module.all_modules.33.NIN_3.b
# module.all_modules.34.GroupNorm_0.style.weight
# module.all_modules.34.GroupNorm_0.style.bias
# module.all_modules.34.Conv_0.weight
# module.all_modules.34.Conv_0.bias
# module.all_modules.34.Dense_0.weight
# module.all_modules.34.Dense_0.bias
# module.all_modules.34.GroupNorm_1.style.weight
# module.all_modules.34.GroupNorm_1.style.bias
# module.all_modules.34.Conv_1.weight
# module.all_modules.34.Conv_1.bias
# module.all_modules.34.Conv_2.weight
# module.all_modules.34.Conv_2.bias
# module.all_modules.35.GroupNorm_0.style.weight
# module.all_modules.35.GroupNorm_0.style.bias
# module.all_modules.35.Conv_0.weight
# module.all_modules.35.Conv_0.bias
# module.all_modules.35.Dense_0.weight
# module.all_modules.35.Dense_0.bias
# module.all_modules.35.GroupNorm_1.style.weight
# module.all_modules.35.GroupNorm_1.style.bias
# module.all_modules.35.Conv_1.weight
# module.all_modules.35.Conv_1.bias
# module.all_modules.35.Conv_2.weight
# module.all_modules.35.Conv_2.bias
# module.all_modules.36.GroupNorm_0.style.weight
# module.all_modules.36.GroupNorm_0.style.bias
# module.all_modules.36.Conv_0.weight
# module.all_modules.36.Conv_0.bias
# module.all_modules.36.Dense_0.weight
# module.all_modules.36.Dense_0.bias
# module.all_modules.36.GroupNorm_1.style.weight
# module.all_modules.36.GroupNorm_1.style.bias
# module.all_modules.36.Conv_1.weight
# module.all_modules.36.Conv_1.bias
# module.all_modules.36.Conv_2.weight
# module.all_modules.36.Conv_2.bias
# module.all_modules.37.GroupNorm_0.style.weight
# module.all_modules.37.GroupNorm_0.style.bias
# module.all_modules.37.Conv_0.weight
# module.all_modules.37.Conv_0.bias
# module.all_modules.37.Dense_0.weight
# module.all_modules.37.Dense_0.bias
# module.all_modules.37.GroupNorm_1.style.weight
# module.all_modules.37.GroupNorm_1.style.bias
# module.all_modules.37.Conv_1.weight
# module.all_modules.37.Conv_1.bias
# module.all_modules.37.Conv_2.weight
# module.all_modules.37.Conv_2.bias
# module.all_modules.38.weight
# module.all_modules.38.bias
# module.all_modules.39.weight
# module.all_modules.39.bias
# module.z_transform.1.weight
# module.z_transform.1.bias
# module.z_transform.3.weight
# module.z_transform.3.bias
# module.z_transform.5.weight
# module.z_transform.5.bias
# module.z_transform.7.weight
# module.z_transform.7.bias
# module.z_transform.9.weight
# module.z_transform.9.bias

# %%
for key in list(ckpt2.keys()):
    ckpt2[key[7:]] = ckpt2.pop(key)

# %%
print(len(ckpt2.keys()))
print(len(list(ckpt2.keys())))

for key in list(ckpt2.keys()):
    print(key)
# Out:
# 384
# 384
# all_modules.0.weight
# all_modules.0.bias
# all_modules.1.weight
# all_modules.1.bias
# all_modules.2.weight
# all_modules.2.bias
# all_modules.3.GroupNorm_0.style.weight
# all_modules.3.GroupNorm_0.style.bias
# all_modules.3.Conv_0.weight
# all_modules.3.Conv_0.bias
# all_modules.3.Dense_0.weight
# all_modules.3.Dense_0.bias
# all_modules.3.GroupNorm_1.style.weight
# all_modules.3.GroupNorm_1.style.bias
# all_modules.3.Conv_1.weight
# all_modules.3.Conv_1.bias
# all_modules.4.GroupNorm_0.style.weight
# all_modules.4.GroupNorm_0.style.bias
# all_modules.4.Conv_0.weight
# all_modules.4.Conv_0.bias
# all_modules.4.Dense_0.weight
# all_modules.4.Dense_0.bias
# all_modules.4.GroupNorm_1.style.weight
# all_modules.4.GroupNorm_1.style.bias
# all_modules.4.Conv_1.weight
# all_modules.4.Conv_1.bias
# all_modules.5.GroupNorm_0.style.weight
# all_modules.5.GroupNorm_0.style.bias
# all_modules.5.Conv_0.weight
# all_modules.5.Conv_0.bias
# all_modules.5.Dense_0.weight
# all_modules.5.Dense_0.bias
# all_modules.5.GroupNorm_1.style.weight
# all_modules.5.GroupNorm_1.style.bias
# all_modules.5.Conv_1.weight
# all_modules.5.Conv_1.bias
# all_modules.5.Conv_2.weight
# all_modules.5.Conv_2.bias
# all_modules.6.Conv2d_0.weight
# all_modules.6.Conv2d_0.bias
# all_modules.7.GroupNorm_0.style.weight
# all_modules.7.GroupNorm_0.style.bias
# all_modules.7.Conv_0.weight
# all_modules.7.Conv_0.bias
# all_modules.7.Dense_0.weight
# all_modules.7.Dense_0.bias
# all_modules.7.GroupNorm_1.style.weight
# all_modules.7.GroupNorm_1.style.bias
# all_modules.7.Conv_1.weight
# all_modules.7.Conv_1.bias
# all_modules.7.Conv_2.weight
# all_modules.7.Conv_2.bias
# all_modules.8.GroupNorm_0.weight
# all_modules.8.GroupNorm_0.bias
# all_modules.8.NIN_0.W
# all_modules.8.NIN_0.b
# all_modules.8.NIN_1.W
# all_modules.8.NIN_1.b
# all_modules.8.NIN_2.W
# all_modules.8.NIN_2.b
# all_modules.8.NIN_3.W
# all_modules.8.NIN_3.b
# all_modules.9.GroupNorm_0.style.weight
# all_modules.9.GroupNorm_0.style.bias
# all_modules.9.Conv_0.weight
# all_modules.9.Conv_0.bias
# all_modules.9.Dense_0.weight
# all_modules.9.Dense_0.bias
# all_modules.9.GroupNorm_1.style.weight
# all_modules.9.GroupNorm_1.style.bias
# all_modules.9.Conv_1.weight
# all_modules.9.Conv_1.bias
# all_modules.10.GroupNorm_0.weight
# all_modules.10.GroupNorm_0.bias
# all_modules.10.NIN_0.W
# all_modules.10.NIN_0.b
# all_modules.10.NIN_1.W
# all_modules.10.NIN_1.b
# all_modules.10.NIN_2.W
# all_modules.10.NIN_2.b
# all_modules.10.NIN_3.W
# all_modules.10.NIN_3.b
# all_modules.11.GroupNorm_0.style.weight
# all_modules.11.GroupNorm_0.style.bias
# all_modules.11.Conv_0.weight
# all_modules.11.Conv_0.bias
# all_modules.11.Dense_0.weight
# all_modules.11.Dense_0.bias
# all_modules.11.GroupNorm_1.style.weight
# all_modules.11.GroupNorm_1.style.bias
# all_modules.11.Conv_1.weight
# all_modules.11.Conv_1.bias
# all_modules.11.Conv_2.weight
# all_modules.11.Conv_2.bias
# all_modules.12.Conv2d_0.weight
# all_modules.12.Conv2d_0.bias
# all_modules.13.GroupNorm_0.style.weight
# all_modules.13.GroupNorm_0.style.bias
# all_modules.13.Conv_0.weight
# all_modules.13.Conv_0.bias
# all_modules.13.Dense_0.weight
# all_modules.13.Dense_0.bias
# all_modules.13.GroupNorm_1.style.weight
# all_modules.13.GroupNorm_1.style.bias
# all_modules.13.Conv_1.weight
# all_modules.13.Conv_1.bias
# all_modules.14.GroupNorm_0.style.weight
# all_modules.14.GroupNorm_0.style.bias
# all_modules.14.Conv_0.weight
# all_modules.14.Conv_0.bias
# all_modules.14.Dense_0.weight
# all_modules.14.Dense_0.bias
# all_modules.14.GroupNorm_1.style.weight
# all_modules.14.GroupNorm_1.style.bias
# all_modules.14.Conv_1.weight
# all_modules.14.Conv_1.bias
# all_modules.15.GroupNorm_0.style.weight
# all_modules.15.GroupNorm_0.style.bias
# all_modules.15.Conv_0.weight
# all_modules.15.Conv_0.bias
# all_modules.15.Dense_0.weight
# all_modules.15.Dense_0.bias
# all_modules.15.GroupNorm_1.style.weight
# all_modules.15.GroupNorm_1.style.bias
# all_modules.15.Conv_1.weight
# all_modules.15.Conv_1.bias
# all_modules.15.Conv_2.weight
# all_modules.15.Conv_2.bias
# all_modules.16.Conv2d_0.weight
# all_modules.16.Conv2d_0.bias
# all_modules.17.GroupNorm_0.style.weight
# all_modules.17.GroupNorm_0.style.bias
# all_modules.17.Conv_0.weight
# all_modules.17.Conv_0.bias
# all_modules.17.Dense_0.weight
# all_modules.17.Dense_0.bias
# all_modules.17.GroupNorm_1.style.weight
# all_modules.17.GroupNorm_1.style.bias
# all_modules.17.Conv_1.weight
# all_modules.17.Conv_1.bias
# all_modules.18.GroupNorm_0.style.weight
# all_modules.18.GroupNorm_0.style.bias
# all_modules.18.Conv_0.weight
# all_modules.18.Conv_0.bias
# all_modules.18.Dense_0.weight
# all_modules.18.Dense_0.bias
# all_modules.18.GroupNorm_1.style.weight
# all_modules.18.GroupNorm_1.style.bias
# all_modules.18.Conv_1.weight
# all_modules.18.Conv_1.bias
# all_modules.19.GroupNorm_0.style.weight
# all_modules.19.GroupNorm_0.style.bias
# all_modules.19.Conv_0.weight
# all_modules.19.Conv_0.bias
# all_modules.19.Dense_0.weight
# all_modules.19.Dense_0.bias
# all_modules.19.GroupNorm_1.style.weight
# all_modules.19.GroupNorm_1.style.bias
# all_modules.19.Conv_1.weight
# all_modules.19.Conv_1.bias
# all_modules.20.GroupNorm_0.weight
# all_modules.20.GroupNorm_0.bias
# all_modules.20.NIN_0.W
# all_modules.20.NIN_0.b
# all_modules.20.NIN_1.W
# all_modules.20.NIN_1.b
# all_modules.20.NIN_2.W
# all_modules.20.NIN_2.b
# all_modules.20.NIN_3.W
# all_modules.20.NIN_3.b
# all_modules.21.GroupNorm_0.style.weight
# all_modules.21.GroupNorm_0.style.bias
# all_modules.21.Conv_0.weight
# all_modules.21.Conv_0.bias
# all_modules.21.Dense_0.weight
# all_modules.21.Dense_0.bias
# all_modules.21.GroupNorm_1.style.weight
# all_modules.21.GroupNorm_1.style.bias
# all_modules.21.Conv_1.weight
# all_modules.21.Conv_1.bias
# all_modules.22.GroupNorm_0.style.weight
# all_modules.22.GroupNorm_0.style.bias
# all_modules.22.Conv_0.weight
# all_modules.22.Conv_0.bias
# all_modules.22.Dense_0.weight
# all_modules.22.Dense_0.bias
# all_modules.22.GroupNorm_1.style.weight
# all_modules.22.GroupNorm_1.style.bias
# all_modules.22.Conv_1.weight
# all_modules.22.Conv_1.bias
# all_modules.22.Conv_2.weight
# all_modules.22.Conv_2.bias
# all_modules.23.GroupNorm_0.style.weight
# all_modules.23.GroupNorm_0.style.bias
# all_modules.23.Conv_0.weight
# all_modules.23.Conv_0.bias
# all_modules.23.Dense_0.weight
# all_modules.23.Dense_0.bias
# all_modules.23.GroupNorm_1.style.weight
# all_modules.23.GroupNorm_1.style.bias
# all_modules.23.Conv_1.weight
# all_modules.23.Conv_1.bias
# all_modules.23.Conv_2.weight
# all_modules.23.Conv_2.bias
# all_modules.24.GroupNorm_0.style.weight
# all_modules.24.GroupNorm_0.style.bias
# all_modules.24.Conv_0.weight
# all_modules.24.Conv_0.bias
# all_modules.24.Dense_0.weight
# all_modules.24.Dense_0.bias
# all_modules.24.GroupNorm_1.style.weight
# all_modules.24.GroupNorm_1.style.bias
# all_modules.24.Conv_1.weight
# all_modules.24.Conv_1.bias
# all_modules.24.Conv_2.weight
# all_modules.24.Conv_2.bias
# all_modules.25.GroupNorm_0.style.weight
# all_modules.25.GroupNorm_0.style.bias
# all_modules.25.Conv_0.weight
# all_modules.25.Conv_0.bias
# all_modules.25.Dense_0.weight
# all_modules.25.Dense_0.bias
# all_modules.25.GroupNorm_1.style.weight
# all_modules.25.GroupNorm_1.style.bias
# all_modules.25.Conv_1.weight
# all_modules.25.Conv_1.bias
# all_modules.25.Conv_2.weight
# all_modules.25.Conv_2.bias
# all_modules.26.GroupNorm_0.style.weight
# all_modules.26.GroupNorm_0.style.bias
# all_modules.26.Conv_0.weight
# all_modules.26.Conv_0.bias
# all_modules.26.Dense_0.weight
# all_modules.26.Dense_0.bias
# all_modules.26.GroupNorm_1.style.weight
# all_modules.26.GroupNorm_1.style.bias
# all_modules.26.Conv_1.weight
# all_modules.26.Conv_1.bias
# all_modules.26.Conv_2.weight
# all_modules.26.Conv_2.bias
# all_modules.27.GroupNorm_0.style.weight
# all_modules.27.GroupNorm_0.style.bias
# all_modules.27.Conv_0.weight
# all_modules.27.Conv_0.bias
# all_modules.27.Dense_0.weight
# all_modules.27.Dense_0.bias
# all_modules.27.GroupNorm_1.style.weight
# all_modules.27.GroupNorm_1.style.bias
# all_modules.27.Conv_1.weight
# all_modules.27.Conv_1.bias
# all_modules.27.Conv_2.weight
# all_modules.27.Conv_2.bias
# all_modules.28.GroupNorm_0.style.weight
# all_modules.28.GroupNorm_0.style.bias
# all_modules.28.Conv_0.weight
# all_modules.28.Conv_0.bias
# all_modules.28.Dense_0.weight
# all_modules.28.Dense_0.bias
# all_modules.28.GroupNorm_1.style.weight
# all_modules.28.GroupNorm_1.style.bias
# all_modules.28.Conv_1.weight
# all_modules.28.Conv_1.bias
# all_modules.28.Conv_2.weight
# all_modules.28.Conv_2.bias
# all_modules.29.GroupNorm_0.style.weight
# all_modules.29.GroupNorm_0.style.bias
# all_modules.29.Conv_0.weight
# all_modules.29.Conv_0.bias
# all_modules.29.Dense_0.weight
# all_modules.29.Dense_0.bias
# all_modules.29.GroupNorm_1.style.weight
# all_modules.29.GroupNorm_1.style.bias
# all_modules.29.Conv_1.weight
# all_modules.29.Conv_1.bias
# all_modules.29.Conv_2.weight
# all_modules.29.Conv_2.bias
# all_modules.30.GroupNorm_0.style.weight
# all_modules.30.GroupNorm_0.style.bias
# all_modules.30.Conv_0.weight
# all_modules.30.Conv_0.bias
# all_modules.30.Dense_0.weight
# all_modules.30.Dense_0.bias
# all_modules.30.GroupNorm_1.style.weight
# all_modules.30.GroupNorm_1.style.bias
# all_modules.30.Conv_1.weight
# all_modules.30.Conv_1.bias
# all_modules.30.Conv_2.weight
# all_modules.30.Conv_2.bias
# all_modules.31.GroupNorm_0.style.weight
# all_modules.31.GroupNorm_0.style.bias
# all_modules.31.Conv_0.weight
# all_modules.31.Conv_0.bias
# all_modules.31.Dense_0.weight
# all_modules.31.Dense_0.bias
# all_modules.31.GroupNorm_1.style.weight
# all_modules.31.GroupNorm_1.style.bias
# all_modules.31.Conv_1.weight
# all_modules.31.Conv_1.bias
# all_modules.31.Conv_2.weight
# all_modules.31.Conv_2.bias
# all_modules.32.GroupNorm_0.style.weight
# all_modules.32.GroupNorm_0.style.bias
# all_modules.32.Conv_0.weight
# all_modules.32.Conv_0.bias
# all_modules.32.Dense_0.weight
# all_modules.32.Dense_0.bias
# all_modules.32.GroupNorm_1.style.weight
# all_modules.32.GroupNorm_1.style.bias
# all_modules.32.Conv_1.weight
# all_modules.32.Conv_1.bias
# all_modules.32.Conv_2.weight
# all_modules.32.Conv_2.bias
# all_modules.33.GroupNorm_0.weight
# all_modules.33.GroupNorm_0.bias
# all_modules.33.NIN_0.W
# all_modules.33.NIN_0.b
# all_modules.33.NIN_1.W
# all_modules.33.NIN_1.b
# all_modules.33.NIN_2.W
# all_modules.33.NIN_2.b
# all_modules.33.NIN_3.W
# all_modules.33.NIN_3.b
# all_modules.34.GroupNorm_0.style.weight
# all_modules.34.GroupNorm_0.style.bias
# all_modules.34.Conv_0.weight
# all_modules.34.Conv_0.bias
# all_modules.34.Dense_0.weight
# all_modules.34.Dense_0.bias
# all_modules.34.GroupNorm_1.style.weight
# all_modules.34.GroupNorm_1.style.bias
# all_modules.34.Conv_1.weight
# all_modules.34.Conv_1.bias
# all_modules.34.Conv_2.weight
# all_modules.34.Conv_2.bias
# all_modules.35.GroupNorm_0.style.weight
# all_modules.35.GroupNorm_0.style.bias
# all_modules.35.Conv_0.weight
# all_modules.35.Conv_0.bias
# all_modules.35.Dense_0.weight
# all_modules.35.Dense_0.bias
# all_modules.35.GroupNorm_1.style.weight
# all_modules.35.GroupNorm_1.style.bias
# all_modules.35.Conv_1.weight
# all_modules.35.Conv_1.bias
# all_modules.35.Conv_2.weight
# all_modules.35.Conv_2.bias
# all_modules.36.GroupNorm_0.style.weight
# all_modules.36.GroupNorm_0.style.bias
# all_modules.36.Conv_0.weight
# all_modules.36.Conv_0.bias
# all_modules.36.Dense_0.weight
# all_modules.36.Dense_0.bias
# all_modules.36.GroupNorm_1.style.weight
# all_modules.36.GroupNorm_1.style.bias
# all_modules.36.Conv_1.weight
# all_modules.36.Conv_1.bias
# all_modules.36.Conv_2.weight
# all_modules.36.Conv_2.bias
# all_modules.37.GroupNorm_0.style.weight
# all_modules.37.GroupNorm_0.style.bias
# all_modules.37.Conv_0.weight
# all_modules.37.Conv_0.bias
# all_modules.37.Dense_0.weight
# all_modules.37.Dense_0.bias
# all_modules.37.GroupNorm_1.style.weight
# all_modules.37.GroupNorm_1.style.bias
# all_modules.37.Conv_1.weight
# all_modules.37.Conv_1.bias
# all_modules.37.Conv_2.weight
# all_modules.37.Conv_2.bias
# all_modules.38.weight
# all_modules.38.bias
# all_modules.39.weight
# all_modules.39.bias
# z_transform.1.weight
# z_transform.1.bias
# z_transform.3.weight
# z_transform.3.bias
# z_transform.5.weight
# z_transform.5.bias
# z_transform.7.weight
# z_transform.7.bias
# z_transform.9.weight
# z_transform.9.bias
